# %%
run main.py
# Out:
# data/train_images not found, extracting data/train_images.zip
# data/test_images not found, extracting data/test_images.zip
# data/val_images not found, making a validation set
# /Users/marshall/Documents/kaggle/traffic_sign_recognition/model.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# /Users/marshall/Documents/kaggle/traffic_sign_recognition/main.py:62: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   100. * batch_idx / len(train_loader), loss.data[0]))
# Train Epoch: 1 [0/35339 (0%)]	Loss: 3.808295
# Train Epoch: 1 [640/35339 (2%)]	Loss: 3.811476
# Train Epoch: 1 [1280/35339 (4%)]	Loss: 3.770142
# Train Epoch: 1 [1920/35339 (5%)]	Loss: 3.766791
# Train Epoch: 1 [2560/35339 (7%)]	Loss: 3.750371
# Train Epoch: 1 [3200/35339 (9%)]	Loss: 3.701356
# ...
